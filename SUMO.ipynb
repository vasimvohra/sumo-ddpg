# %%
import os
import sys
import subprocess
from google.colab import drive

def setup_sumo_rl_environment():
    print("\n🔗 Mounting Google Drive...")
    drive.mount('/content/drive', force_remount=True)
    print("✔ Google Drive mounted.\n")

    # Set project folder in Google Drive (change if needed)
    project_path = '/content/drive/MyDrive/Colab Notebooks/SUMO_DDPG'
    print("📁 Project path is:", project_path)

    # Install SUMO traffic simulator and tools
    print("\n📦 Installing SUMO and SUMO tools ...")
    subprocess.run(['apt', 'update', '-qq'], check=True)
    subprocess.run(['apt-get', 'install', '-y', '-qq', 'sumo', 'sumo-tools'], check=True)
    print("✔ SUMO installation complete.\n")
    # !pip install TraCI
    # Set SUMO_HOME environment variable for Python SUMO modules
    os.environ['SUMO_HOME'] = '/usr/share/sumo'
    print("🌐 Set SUMO_HOME to /usr/share/sumo")



    # Add only Google Drive project path to Python path (no local copy)
    if project_path not in sys.path:
        sys.path.append(project_path)
        print(f"➕ Added Drive project path to Python path: {project_path}")

    print("\n✅ SUMO + RL environment setup complete!\n")
    print(f"RUN & EDIT FILES DIRECTLY HERE: {project_path}")
    print(f"SUMO_HOME is set to: {os.environ['SUMO_HOME']}")
    print("\n🦾 Next: Run your RL code from Drive, e.g.:")
    print(f"!python \"{project_path}/Main.py\"")

    return project_path

# Execute setup (run this cell at the top of your notebook every session)
project_dir = setup_sumo_rl_environment()
# Out:
# 🔗 Mounting Google Drive...
# Mounted at /content/drive
# ✔ Google Drive mounted.
#
# 📁 Project path is: /content/drive/MyDrive/Colab Notebooks/SUMO_DDPG
#
# 📦 Installing SUMO and SUMO tools ...
# ✔ SUMO installation complete.
#
# Requirement already satisfied: TraCI in /usr/local/lib/python3.12/dist-packages (1.24.0)
# Requirement already satisfied: sumolib>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from TraCI) (1.24.0)
# 🌐 Set SUMO_HOME to /usr/share/sumo
# ➕ Added Drive project path to Python path: /content/drive/MyDrive/Colab Notebooks/SUMO_DDPG
#
# ✅ SUMO + RL environment setup complete!
#
# RUN & EDIT FILES DIRECTLY HERE: /content/drive/MyDrive/Colab Notebooks/SUMO_DDPG
# SUMO_HOME is set to: /usr/share/sumo
#
# 🦾 Next: Run your RL code from Drive, e.g.:
# !python "/content/drive/MyDrive/Colab Notebooks/SUMO_DDPG/Main.py"

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/SUMO_DDPG')
print("Current working directory reset to:", os.getcwd())
# Out:
# Current working directory reset to: /content/drive/MyDrive/Colab Notebooks/SUMO_DDPG

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/SUMO_DDPG/Main.py"
# Out:
# Warning: GUI not available in Colab, using headless mode
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
# Episode duration: 1s (1,000 steps)
# Total episodes: 100
# Estimated training time per episode: 0.0 minutes
# Starting SUMO-V2X Training for 100 episodes...
# Episode 0/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
# /content/drive/MyDrive/Colab Notebooks/SUMO_DDPG/ddpg_torch.py:39: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   state = T.tensor([observation], dtype=T.float).to(self.actor.device)
#   Step 0, Global Reward: -10.7905, V2V Success: 0.00
#   Step 50, Global Reward: -10.7624, V2V Success: 0.00
#   Step 100, Global Reward: -5.5275, V2V Success: 0.20
#   Step 150, Global Reward: -5.9327, V2V Success: 0.40
#   Step 200, Global Reward: -6.2499, V2V Success: 0.40
#   Step 250, Global Reward: -5.9472, V2V Success: 0.40
#   Step 300, Global Reward: -6.1041, V2V Success: 0.40
#   Step 350, Global Reward: -5.9472, V2V Success: 0.40
#   Step 400, Global Reward: -5.9259, V2V Success: 0.40
#   Step 450, Global Reward: -4.5335, V2V Success: 0.60
#   Step 500, Global Reward: -5.0135, V2V Success: 0.60
#   Step 550, Global Reward: -5.0335, V2V Success: 0.60
#   Step 600, Global Reward: -5.0408, V2V Success: 0.60
#   Step 650, Global Reward: -5.0081, V2V Success: 0.60
#   Step 700, Global Reward: -5.0952, V2V Success: 0.60
#   Step 750, Global Reward: -5.1542, V2V Success: 0.60
#   Step 800, Global Reward: -5.1166, V2V Success: 0.60
#   Step 850, Global Reward: -5.2083, V2V Success: 0.60
#   Step 900, Global Reward: -5.0035, V2V Success: 0.60
#   Step 950, Global Reward: -5.0758, V2V Success: 0.60
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# Saved model at episode 0
# Episode 1/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.5651, V2V Success: 0.00
#   Step 50, Global Reward: -8.5888, V2V Success: 0.00
#   Step 100, Global Reward: -8.4141, V2V Success: 0.00
#   Step 150, Global Reward: -8.2562, V2V Success: 0.00
#   Step 200, Global Reward: -8.1938, V2V Success: 0.00
#   Step 250, Global Reward: -8.2368, V2V Success: 0.00
#   Step 300, Global Reward: -7.9286, V2V Success: 0.00
#   Step 350, Global Reward: -7.8603, V2V Success: 0.00
#   Step 400, Global Reward: -7.8523, V2V Success: 0.20
#   Step 450, Global Reward: -7.8666, V2V Success: 0.20
#   Step 500, Global Reward: -7.5371, V2V Success: 0.20
#   Step 550, Global Reward: -7.9405, V2V Success: 0.20
#   Step 600, Global Reward: -7.9177, V2V Success: 0.20
#   Step 650, Global Reward: -7.3680, V2V Success: 0.20
#   Step 700, Global Reward: -7.2408, V2V Success: 0.40
#   Step 750, Global Reward: -6.5611, V2V Success: 0.60
#   Step 800, Global Reward: -7.1346, V2V Success: 0.60
#   Step 850, Global Reward: -6.4387, V2V Success: 0.60
#   Step 900, Global Reward: -6.8170, V2V Success: 0.60
#   Step 950, Global Reward: -5.9633, V2V Success: 0.60
# Episode 2/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.4497, V2V Success: 0.00
#   Step 50, Global Reward: -8.2903, V2V Success: 0.20
#   Step 100, Global Reward: -7.7858, V2V Success: 0.20
#   Step 150, Global Reward: -8.1714, V2V Success: 0.40
#   Step 200, Global Reward: -7.6363, V2V Success: 0.40
#   Step 250, Global Reward: -7.6646, V2V Success: 0.40
#   Step 300, Global Reward: -7.4923, V2V Success: 0.40
#   Step 350, Global Reward: -7.4694, V2V Success: 0.40
#   Step 400, Global Reward: -7.4106, V2V Success: 0.40
#   Step 450, Global Reward: -7.4154, V2V Success: 0.40
#   Step 500, Global Reward: -7.4037, V2V Success: 0.40
#   Step 550, Global Reward: -7.5017, V2V Success: 0.40
#   Step 600, Global Reward: -7.6277, V2V Success: 0.40
#   Step 650, Global Reward: -7.4408, V2V Success: 0.40
#   Step 700, Global Reward: -7.5290, V2V Success: 0.40
#   Step 750, Global Reward: -7.4798, V2V Success: 0.40
#   Step 800, Global Reward: -7.3808, V2V Success: 0.40
#   Step 850, Global Reward: -7.7090, V2V Success: 0.40
#   Step 900, Global Reward: -7.5859, V2V Success: 0.40
#   Step 950, Global Reward: -7.7350, V2V Success: 0.40
# Episode 3/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.2853, V2V Success: 0.00
#   Step 50, Global Reward: -5.1940, V2V Success: 0.40
#   Step 100, Global Reward: -5.0501, V2V Success: 0.60
#   Step 150, Global Reward: -5.7038, V2V Success: 0.60
#   Step 200, Global Reward: -5.2324, V2V Success: 0.60
#   Step 250, Global Reward: -5.7254, V2V Success: 0.60
#   Step 300, Global Reward: -6.0754, V2V Success: 0.60
#   Step 350, Global Reward: -6.0754, V2V Success: 0.60
#   Step 400, Global Reward: -6.0754, V2V Success: 0.60
#   Step 450, Global Reward: -6.0754, V2V Success: 0.60
#   Step 500, Global Reward: -6.0733, V2V Success: 0.60
#   Step 550, Global Reward: -6.0733, V2V Success: 0.60
#   Step 600, Global Reward: -6.3131, V2V Success: 0.60
#   Step 650, Global Reward: -6.9251, V2V Success: 0.60
#   Step 700, Global Reward: -7.1820, V2V Success: 0.60
#   Step 750, Global Reward: -5.9208, V2V Success: 0.60
#   Step 800, Global Reward: -5.8547, V2V Success: 0.60
#   Step 850, Global Reward: -5.8547, V2V Success: 0.60
#   Step 900, Global Reward: -5.8547, V2V Success: 0.60
#   Step 950, Global Reward: -5.2447, V2V Success: 0.60
# Episode 4/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -10.3567, V2V Success: 0.00
#   Step 50, Global Reward: -7.2455, V2V Success: 0.20
#   Step 100, Global Reward: -4.4953, V2V Success: 0.40
#   Step 150, Global Reward: -4.8319, V2V Success: 0.40
#   Step 200, Global Reward: -3.7719, V2V Success: 0.40
#   Step 250, Global Reward: -4.0440, V2V Success: 0.40
#   Step 300, Global Reward: -4.5033, V2V Success: 0.40
#   Step 350, Global Reward: -5.3042, V2V Success: 0.40
#   Step 400, Global Reward: -3.0432, V2V Success: 0.40
#   Step 450, Global Reward: -3.8388, V2V Success: 0.40
#   Step 500, Global Reward: -4.4643, V2V Success: 0.40
#   Step 550, Global Reward: -4.8680, V2V Success: 0.40
#   Step 600, Global Reward: -4.6452, V2V Success: 0.40
#   Step 650, Global Reward: -4.8559, V2V Success: 0.40
#   Step 700, Global Reward: -4.5037, V2V Success: 0.40
#   Step 750, Global Reward: -3.5702, V2V Success: 0.40
#   Step 800, Global Reward: -3.4716, V2V Success: 0.60
#   Step 850, Global Reward: -4.3498, V2V Success: 0.60
#   Step 900, Global Reward: -3.8246, V2V Success: 0.60
#   Step 950, Global Reward: -3.6804, V2V Success: 0.60
# Episode 5/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -8.6555, V2V Success: 0.00
#   Step 50, Global Reward: -7.7899, V2V Success: 0.00
#   Step 100, Global Reward: -7.7932, V2V Success: 0.00
#   Step 150, Global Reward: -7.0164, V2V Success: 0.00
#   Step 200, Global Reward: -7.9151, V2V Success: 0.00
#   Step 250, Global Reward: -8.0925, V2V Success: 0.20
#   Step 300, Global Reward: -7.6910, V2V Success: 0.20
#   Step 350, Global Reward: -6.4747, V2V Success: 0.20
#   Step 400, Global Reward: -6.4288, V2V Success: 0.20
#   Step 450, Global Reward: -6.8510, V2V Success: 0.20
#   Step 500, Global Reward: -6.9441, V2V Success: 0.20
#   Step 550, Global Reward: -6.1692, V2V Success: 0.20
#   Step 600, Global Reward: -6.0597, V2V Success: 0.20
#   Step 650, Global Reward: -6.3251, V2V Success: 0.40
#   Step 700, Global Reward: -6.8070, V2V Success: 0.40
#   Step 750, Global Reward: -6.2933, V2V Success: 0.40
#   Step 800, Global Reward: -6.6919, V2V Success: 0.40
#   Step 850, Global Reward: -6.4788, V2V Success: 0.60
#   Step 900, Global Reward: -5.9263, V2V Success: 0.60
#   Step 950, Global Reward: -6.0305, V2V Success: 0.60
# Episode 6/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -10.6691, V2V Success: 0.00
#   Step 50, Global Reward: -8.4924, V2V Success: 0.00
#   Step 100, Global Reward: -7.9623, V2V Success: 0.00
#   Step 150, Global Reward: -7.7358, V2V Success: 0.00
#   Step 200, Global Reward: -7.7040, V2V Success: 0.20
#   Step 250, Global Reward: -7.2298, V2V Success: 0.20
#   Step 300, Global Reward: -7.0173, V2V Success: 0.20
#   Step 350, Global Reward: -6.9126, V2V Success: 0.20
#   Step 400, Global Reward: -7.2705, V2V Success: 0.20
#   Step 450, Global Reward: -7.6396, V2V Success: 0.20
#   Step 500, Global Reward: -6.5948, V2V Success: 0.20
#   Step 550, Global Reward: -7.3890, V2V Success: 0.20
#   Step 600, Global Reward: -6.3053, V2V Success: 0.40
#   Step 650, Global Reward: -6.2665, V2V Success: 0.40
#   Step 700, Global Reward: -6.3777, V2V Success: 0.40
#   Step 750, Global Reward: -5.3694, V2V Success: 0.40
#   Step 800, Global Reward: -5.4985, V2V Success: 0.40
#   Step 850, Global Reward: -6.3866, V2V Success: 0.40
#   Step 900, Global Reward: -6.5684, V2V Success: 0.60
#   Step 950, Global Reward: -6.0459, V2V Success: 0.60
# Episode 7/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.8079, V2V Success: 0.00
#   Step 50, Global Reward: -7.9054, V2V Success: 0.00
#   Step 100, Global Reward: -7.1263, V2V Success: 0.20
#   Step 150, Global Reward: -6.9465, V2V Success: 0.20
#   Step 200, Global Reward: -6.6255, V2V Success: 0.20
#   Step 250, Global Reward: -6.9255, V2V Success: 0.20
#   Step 300, Global Reward: -6.9976, V2V Success: 0.20
#   Step 350, Global Reward: -4.8680, V2V Success: 0.40
#   Step 400, Global Reward: -4.7784, V2V Success: 0.60
#   Step 450, Global Reward: -4.8259, V2V Success: 0.60
#   Step 500, Global Reward: -5.2016, V2V Success: 0.60
#   Step 550, Global Reward: -5.2998, V2V Success: 0.60
#   Step 600, Global Reward: -4.5602, V2V Success: 0.60
#   Step 650, Global Reward: -4.8355, V2V Success: 0.60
#   Step 700, Global Reward: -4.8865, V2V Success: 0.80
#   Step 750, Global Reward: -5.1003, V2V Success: 0.80
#   Step 800, Global Reward: -4.6949, V2V Success: 0.80
#   Step 850, Global Reward: -4.8928, V2V Success: 0.80
#   Step 900, Global Reward: -4.6774, V2V Success: 0.80
#   Step 950, Global Reward: -4.6395, V2V Success: 0.80
# Episode 8/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.5643, V2V Success: 0.00
#   Step 50, Global Reward: -7.9276, V2V Success: 0.00
#   Step 100, Global Reward: -7.4649, V2V Success: 0.00
#   Step 150, Global Reward: -8.2131, V2V Success: 0.00
#   Step 200, Global Reward: -7.9356, V2V Success: 0.00
#   Step 250, Global Reward: -6.5673, V2V Success: 0.20
#   Step 300, Global Reward: -7.6681, V2V Success: 0.20
#   Step 350, Global Reward: -6.9513, V2V Success: 0.20
#   Step 400, Global Reward: -6.0345, V2V Success: 0.20
#   Step 450, Global Reward: -6.5666, V2V Success: 0.20
#   Step 500, Global Reward: -6.1271, V2V Success: 0.20
#   Step 550, Global Reward: -6.5033, V2V Success: 0.20
#   Step 600, Global Reward: -5.9384, V2V Success: 0.20
#   Step 650, Global Reward: -3.2144, V2V Success: 0.80
#   Step 700, Global Reward: -4.6405, V2V Success: 0.80
#   Step 750, Global Reward: -4.6143, V2V Success: 0.80
#   Step 800, Global Reward: -4.1734, V2V Success: 0.80
#   Step 850, Global Reward: -4.7012, V2V Success: 0.80
#   Step 900, Global Reward: -5.5028, V2V Success: 0.80
#   Step 950, Global Reward: -4.6786, V2V Success: 0.80
# Episode 9/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -8.4528, V2V Success: 0.00
#   Step 50, Global Reward: -5.9177, V2V Success: 0.20
#   Step 100, Global Reward: -5.6735, V2V Success: 0.20
#   Step 150, Global Reward: -6.0541, V2V Success: 0.20
#   Step 200, Global Reward: -6.1861, V2V Success: 0.20
#   Step 250, Global Reward: -6.5416, V2V Success: 0.20
#   Step 300, Global Reward: -6.7308, V2V Success: 0.20
#   Step 350, Global Reward: -7.1325, V2V Success: 0.20
#   Step 400, Global Reward: -6.4116, V2V Success: 0.20
#   Step 450, Global Reward: -6.4751, V2V Success: 0.20
#   Step 500, Global Reward: -6.4486, V2V Success: 0.20
#   Step 550, Global Reward: -6.4406, V2V Success: 0.20
#   Step 600, Global Reward: -6.3999, V2V Success: 0.20
#   Step 650, Global Reward: -6.1714, V2V Success: 0.40
#   Step 700, Global Reward: -5.4851, V2V Success: 0.40
#   Step 750, Global Reward: -4.8686, V2V Success: 0.40
#   Step 800, Global Reward: -5.0779, V2V Success: 0.40
#   Step 850, Global Reward: -4.3693, V2V Success: 0.40
#   Step 900, Global Reward: -4.8205, V2V Success: 0.40
#   Step 950, Global Reward: -5.3867, V2V Success: 0.40
# Episode 10/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.3719, V2V Success: 0.00
#   Step 50, Global Reward: -8.3147, V2V Success: 0.00
#   Step 100, Global Reward: -8.2687, V2V Success: 0.00
#   Step 150, Global Reward: -7.9749, V2V Success: 0.00
#   Step 200, Global Reward: -6.8270, V2V Success: 0.00
#   Step 250, Global Reward: -6.6130, V2V Success: 0.20
#   Step 300, Global Reward: -6.6169, V2V Success: 0.20
#   Step 350, Global Reward: -6.4324, V2V Success: 0.20
#   Step 400, Global Reward: -6.2891, V2V Success: 0.40
#   Step 450, Global Reward: -6.4104, V2V Success: 0.40
#   Step 500, Global Reward: -5.7070, V2V Success: 0.40
#   Step 550, Global Reward: -5.6918, V2V Success: 0.40
#   Step 600, Global Reward: -5.6422, V2V Success: 0.40
#   Step 650, Global Reward: -4.5706, V2V Success: 0.40
#   Step 700, Global Reward: -4.5115, V2V Success: 0.40
#   Step 750, Global Reward: -4.6079, V2V Success: 0.40
#   Step 800, Global Reward: -5.1408, V2V Success: 0.40
#   Step 850, Global Reward: -6.0963, V2V Success: 0.40
#   Step 900, Global Reward: -4.7325, V2V Success: 0.40
#   Step 950, Global Reward: -4.9540, V2V Success: 0.40
# Episode 11/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -8.4149, V2V Success: 0.00
#   Step 50, Global Reward: -5.8719, V2V Success: 0.00
#   Step 100, Global Reward: -6.3849, V2V Success: 0.00
#   Step 150, Global Reward: -6.1778, V2V Success: 0.20
#   Step 200, Global Reward: -6.4686, V2V Success: 0.20
#   Step 250, Global Reward: -5.8899, V2V Success: 0.20
#   Step 300, Global Reward: -6.0091, V2V Success: 0.20
#   Step 350, Global Reward: -6.1772, V2V Success: 0.20
#   Step 400, Global Reward: -5.6142, V2V Success: 0.20
#   Step 450, Global Reward: -5.8474, V2V Success: 0.20
#   Step 500, Global Reward: -5.6195, V2V Success: 0.20
#   Step 550, Global Reward: -5.9562, V2V Success: 0.20
#   Step 600, Global Reward: -5.6725, V2V Success: 0.20
#   Step 650, Global Reward: -5.5702, V2V Success: 0.20
#   Step 700, Global Reward: -6.0629, V2V Success: 0.20
#   Step 750, Global Reward: -5.9791, V2V Success: 0.20
#   Step 800, Global Reward: -7.1197, V2V Success: 0.20
#   Step 850, Global Reward: -5.1804, V2V Success: 0.20
#   Step 900, Global Reward: -4.7390, V2V Success: 0.60
#   Step 950, Global Reward: -6.6051, V2V Success: 0.60
# Episode 12/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -10.1057, V2V Success: 0.00
#   Step 50, Global Reward: -7.8035, V2V Success: 0.20
#   Step 100, Global Reward: -5.6838, V2V Success: 0.40
#   Step 150, Global Reward: -6.8588, V2V Success: 0.40
#   Step 200, Global Reward: -5.3651, V2V Success: 0.40
#   Step 250, Global Reward: -4.8213, V2V Success: 0.40
#   Step 300, Global Reward: -5.2102, V2V Success: 0.60
#   Step 350, Global Reward: -5.2737, V2V Success: 0.80
#   Step 400, Global Reward: -5.4447, V2V Success: 0.80
#   Step 450, Global Reward: -5.5446, V2V Success: 0.80
#   Step 500, Global Reward: -5.5648, V2V Success: 0.80
#   Step 550, Global Reward: -5.5026, V2V Success: 0.80
#   Step 600, Global Reward: -5.4184, V2V Success: 0.80
#   Step 650, Global Reward: -5.3125, V2V Success: 0.80
#   Step 700, Global Reward: -5.3200, V2V Success: 0.80
#   Step 750, Global Reward: -5.2673, V2V Success: 0.80
#   Step 800, Global Reward: -5.2629, V2V Success: 0.80
#   Step 850, Global Reward: -5.2612, V2V Success: 0.80
#   Step 900, Global Reward: -5.3091, V2V Success: 0.80
#   Step 950, Global Reward: -5.2873, V2V Success: 0.80
# Episode 13/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.4134, V2V Success: 0.00
#   Step 50, Global Reward: -5.6114, V2V Success: 0.00
#   Step 100, Global Reward: -6.8688, V2V Success: 0.20
#   Step 150, Global Reward: -7.4335, V2V Success: 0.20
#   Step 200, Global Reward: -7.3370, V2V Success: 0.40
#   Step 250, Global Reward: -7.1809, V2V Success: 0.40
#   Step 300, Global Reward: -7.3501, V2V Success: 0.40
#   Step 350, Global Reward: -6.4298, V2V Success: 0.40
#   Step 400, Global Reward: -6.5842, V2V Success: 0.40
#   Step 450, Global Reward: -6.6307, V2V Success: 0.40
#   Step 500, Global Reward: -6.5271, V2V Success: 0.40
#   Step 550, Global Reward: -6.3478, V2V Success: 0.40
#   Step 600, Global Reward: -5.2260, V2V Success: 0.60
#   Step 650, Global Reward: -4.6365, V2V Success: 0.80
#   Step 700, Global Reward: -5.1142, V2V Success: 0.80
#   Step 750, Global Reward: -4.5695, V2V Success: 0.80
#   Step 800, Global Reward: -4.5417, V2V Success: 0.80
#   Step 850, Global Reward: -4.8232, V2V Success: 0.80
#   Step 900, Global Reward: -5.3726, V2V Success: 0.80
#   Step 950, Global Reward: -5.7014, V2V Success: 0.80
# Episode 14/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.4149, V2V Success: 0.00
#   Step 50, Global Reward: -5.4562, V2V Success: 0.20
#   Step 100, Global Reward: -6.7120, V2V Success: 0.20
#   Step 150, Global Reward: -6.3436, V2V Success: 0.20
#   Step 200, Global Reward: -5.7839, V2V Success: 0.20
#   Step 250, Global Reward: -6.1627, V2V Success: 0.20
#   Step 300, Global Reward: -6.2173, V2V Success: 0.40
#   Step 350, Global Reward: -6.4474, V2V Success: 0.60
#   Step 400, Global Reward: -6.5670, V2V Success: 0.60
#   Step 450, Global Reward: -5.5574, V2V Success: 0.60
#   Step 500, Global Reward: -4.6463, V2V Success: 0.60
#   Step 550, Global Reward: -4.9835, V2V Success: 0.80
#   Step 600, Global Reward: -5.3221, V2V Success: 0.80
#   Step 650, Global Reward: -4.2756, V2V Success: 0.80
#   Step 700, Global Reward: -3.2556, V2V Success: 0.80
#   Step 750, Global Reward: -3.4000, V2V Success: 0.80
#   Step 800, Global Reward: -3.2309, V2V Success: 0.80
#   Step 850, Global Reward: -3.0509, V2V Success: 0.80
#   Step 900, Global Reward: -3.1586, V2V Success: 0.80
#   Step 950, Global Reward: -3.2917, V2V Success: 0.80
# Episode 15/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -10.4401, V2V Success: 0.00
#   Step 50, Global Reward: -6.8996, V2V Success: 0.00
#   Step 100, Global Reward: -7.0016, V2V Success: 0.00
#   Step 150, Global Reward: -7.3873, V2V Success: 0.00
#   Step 200, Global Reward: -7.0873, V2V Success: 0.00
#   Step 250, Global Reward: -6.9338, V2V Success: 0.00
#   Step 300, Global Reward: -6.6938, V2V Success: 0.00
#   Step 350, Global Reward: -7.2717, V2V Success: 0.00
#   Step 400, Global Reward: -7.7630, V2V Success: 0.00
#   Step 450, Global Reward: -6.9140, V2V Success: 0.00
#   Step 500, Global Reward: -7.0626, V2V Success: 0.00
#   Step 550, Global Reward: -6.9109, V2V Success: 0.00
#   Step 600, Global Reward: -6.3271, V2V Success: 0.00
#   Step 650, Global Reward: -7.4992, V2V Success: 0.00
#   Step 700, Global Reward: -7.6869, V2V Success: 0.00
#   Step 750, Global Reward: -7.6800, V2V Success: 0.00
#   Step 800, Global Reward: -7.1178, V2V Success: 0.20
#   Step 850, Global Reward: -6.8413, V2V Success: 0.20
#   Step 900, Global Reward: -5.7252, V2V Success: 0.20
#   Step 950, Global Reward: -5.1636, V2V Success: 0.20
# Episode 16/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.4743, V2V Success: 0.00
#   Step 50, Global Reward: -7.0034, V2V Success: 0.00
#   Step 100, Global Reward: -7.6227, V2V Success: 0.00
#   Step 150, Global Reward: -7.5291, V2V Success: 0.00
#   Step 200, Global Reward: -6.7294, V2V Success: 0.00
#   Step 250, Global Reward: -6.0135, V2V Success: 0.20
#   Step 300, Global Reward: -6.0014, V2V Success: 0.20
#   Step 350, Global Reward: -5.5197, V2V Success: 0.40
#   Step 400, Global Reward: -5.9489, V2V Success: 0.40
#   Step 450, Global Reward: -4.9274, V2V Success: 0.40
#   Step 500, Global Reward: -6.0957, V2V Success: 0.40
#   Step 550, Global Reward: -6.1510, V2V Success: 0.40
#   Step 600, Global Reward: -4.7835, V2V Success: 0.40
#   Step 650, Global Reward: -5.2835, V2V Success: 0.40
#   Step 700, Global Reward: -5.1114, V2V Success: 0.40
#   Step 750, Global Reward: -3.4117, V2V Success: 0.40
#   Step 800, Global Reward: -3.2134, V2V Success: 0.40
#   Step 850, Global Reward: -4.1876, V2V Success: 0.40
#   Step 900, Global Reward: -3.9526, V2V Success: 0.40
#   Step 950, Global Reward: -3.7816, V2V Success: 0.60
# Episode 17/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.4953, V2V Success: 0.00
#   Step 50, Global Reward: -8.5364, V2V Success: 0.20
#   Step 100, Global Reward: -8.5230, V2V Success: 0.20
#   Step 150, Global Reward: -8.5008, V2V Success: 0.20
#   Step 200, Global Reward: -5.5826, V2V Success: 0.20
#   Step 250, Global Reward: -5.1258, V2V Success: 0.40
#   Step 300, Global Reward: -5.1541, V2V Success: 0.40
#   Step 350, Global Reward: -3.6767, V2V Success: 0.60
#   Step 400, Global Reward: -4.2033, V2V Success: 0.60
#   Step 450, Global Reward: -3.6033, V2V Success: 0.60
#   Step 500, Global Reward: -4.2115, V2V Success: 0.60
#   Step 550, Global Reward: -4.5989, V2V Success: 0.60
#   Step 600, Global Reward: -4.5589, V2V Success: 0.60
#   Step 650, Global Reward: -4.5233, V2V Success: 0.60
#   Step 700, Global Reward: -4.5315, V2V Success: 0.60
#   Step 750, Global Reward: -3.9123, V2V Success: 0.60
#   Step 800, Global Reward: -4.6346, V2V Success: 0.60
#   Step 850, Global Reward: -4.5955, V2V Success: 0.60
#   Step 900, Global Reward: -4.5142, V2V Success: 0.60
#   Step 950, Global Reward: -4.6351, V2V Success: 0.60
# Episode 18/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -8.5767, V2V Success: 0.00
#   Step 50, Global Reward: -7.2455, V2V Success: 0.00
#   Step 100, Global Reward: -7.5496, V2V Success: 0.00
#   Step 150, Global Reward: -7.2635, V2V Success: 0.00
#   Step 200, Global Reward: -7.5556, V2V Success: 0.00
#   Step 250, Global Reward: -6.7968, V2V Success: 0.00
#   Step 300, Global Reward: -7.3936, V2V Success: 0.00
#   Step 350, Global Reward: -7.4097, V2V Success: 0.00
#   Step 400, Global Reward: -7.3934, V2V Success: 0.00
#   Step 450, Global Reward: -7.6625, V2V Success: 0.00
#   Step 500, Global Reward: -7.0874, V2V Success: 0.00
#   Step 550, Global Reward: -6.9429, V2V Success: 0.00
#   Step 600, Global Reward: -6.0892, V2V Success: 0.00
#   Step 650, Global Reward: -5.7688, V2V Success: 0.00
#   Step 700, Global Reward: -5.9202, V2V Success: 0.00
#   Step 750, Global Reward: -4.3389, V2V Success: 0.40
#   Step 800, Global Reward: -5.4564, V2V Success: 0.40
#   Step 850, Global Reward: -6.2167, V2V Success: 0.40
#   Step 900, Global Reward: -4.7947, V2V Success: 0.40
#   Step 950, Global Reward: -5.0948, V2V Success: 0.40
# Episode 19/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -10.5023, V2V Success: 0.00
#   Step 50, Global Reward: -8.8111, V2V Success: 0.00
#   Step 100, Global Reward: -6.9315, V2V Success: 0.20
#   Step 150, Global Reward: -7.3836, V2V Success: 0.20
#   Step 200, Global Reward: -7.7986, V2V Success: 0.20
#   Step 250, Global Reward: -8.4313, V2V Success: 0.20
#   Step 300, Global Reward: -6.3603, V2V Success: 0.40
#   Step 350, Global Reward: -5.5650, V2V Success: 0.60
#   Step 400, Global Reward: -6.5872, V2V Success: 0.60
#   Step 450, Global Reward: -7.2520, V2V Success: 0.60
#   Step 500, Global Reward: -6.7133, V2V Success: 0.60
#   Step 550, Global Reward: -4.9699, V2V Success: 0.60
#   Step 600, Global Reward: -5.8235, V2V Success: 0.60
#   Step 650, Global Reward: -5.4484, V2V Success: 0.60
#   Step 700, Global Reward: -5.0401, V2V Success: 0.60
#   Step 750, Global Reward: -5.0684, V2V Success: 0.60
#   Step 800, Global Reward: -5.8738, V2V Success: 0.60
#   Step 850, Global Reward: -6.2085, V2V Success: 0.60
#   Step 900, Global Reward: -5.8779, V2V Success: 0.60
#   Step 950, Global Reward: -4.4610, V2V Success: 0.60
# Episode 20/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -10.1560, V2V Success: 0.00
#   Step 50, Global Reward: -9.0000, V2V Success: 0.00
#   Step 100, Global Reward: -8.7900, V2V Success: 0.00
#   Step 150, Global Reward: -5.5875, V2V Success: 0.20
#   Step 200, Global Reward: -4.5675, V2V Success: 0.40
#   Step 250, Global Reward: -4.1594, V2V Success: 0.40
#   Step 300, Global Reward: -3.8906, V2V Success: 0.40
#   Step 350, Global Reward: -4.0175, V2V Success: 0.40
#   Step 400, Global Reward: -3.7950, V2V Success: 0.60
#   Step 450, Global Reward: -3.6165, V2V Success: 0.60
#   Step 500, Global Reward: -3.7196, V2V Success: 0.60
#   Step 550, Global Reward: -3.5705, V2V Success: 0.60
#   Step 600, Global Reward: -4.0005, V2V Success: 0.60
#   Step 650, Global Reward: -3.9988, V2V Success: 0.60
#   Step 700, Global Reward: -4.6986, V2V Success: 0.80
#   Step 750, Global Reward: -4.6012, V2V Success: 0.80
#   Step 800, Global Reward: -4.5646, V2V Success: 0.80
#   Step 850, Global Reward: -3.8808, V2V Success: 0.80
#   Step 900, Global Reward: -4.8974, V2V Success: 0.80
#   Step 950, Global Reward: -5.6130, V2V Success: 0.80
# Episode 21/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.2113, V2V Success: 0.00
#   Step 50, Global Reward: -8.1419, V2V Success: 0.00
#   Step 100, Global Reward: -7.8540, V2V Success: 0.00
#   Step 150, Global Reward: -7.7525, V2V Success: 0.00
#   Step 200, Global Reward: -4.8420, V2V Success: 0.20
#   Step 250, Global Reward: -6.3673, V2V Success: 0.40
#   Step 300, Global Reward: -3.3190, V2V Success: 0.40
#   Step 350, Global Reward: -3.4568, V2V Success: 0.40
#   Step 400, Global Reward: -3.2756, V2V Success: 0.40
#   Step 450, Global Reward: -4.0188, V2V Success: 0.40
#   Step 500, Global Reward: -3.0881, V2V Success: 0.40
#   Step 550, Global Reward: -3.5699, V2V Success: 0.40
#   Step 600, Global Reward: -3.5645, V2V Success: 0.60
#   Step 650, Global Reward: -3.6473, V2V Success: 0.80
#   Step 700, Global Reward: -3.7134, V2V Success: 0.80
#   Step 750, Global Reward: -3.2113, V2V Success: 0.80
#   Step 800, Global Reward: -2.9627, V2V Success: 0.80
#   Step 850, Global Reward: -2.6553, V2V Success: 0.80
#   Step 900, Global Reward: -2.6899, V2V Success: 0.80
#   Step 950, Global Reward: -2.6347, V2V Success: 0.80
# Episode 22/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -8.9492, V2V Success: 0.00
#   Step 50, Global Reward: -6.7123, V2V Success: 0.00
#   Step 100, Global Reward: -5.3733, V2V Success: 0.00
#   Step 150, Global Reward: -5.5645, V2V Success: 0.00
#   Step 200, Global Reward: -5.0379, V2V Success: 0.00
#   Step 250, Global Reward: -4.9773, V2V Success: 0.00
#   Step 300, Global Reward: -4.7888, V2V Success: 0.00
#   Step 350, Global Reward: -4.7820, V2V Success: 0.00
#   Step 400, Global Reward: -4.8620, V2V Success: 0.20
#   Step 450, Global Reward: -4.9328, V2V Success: 0.20
#   Step 500, Global Reward: -5.5728, V2V Success: 0.20
#   Step 550, Global Reward: -4.9031, V2V Success: 0.20
#   Step 600, Global Reward: -4.9469, V2V Success: 0.20
#   Step 650, Global Reward: -5.5817, V2V Success: 0.20
#   Step 700, Global Reward: -4.2383, V2V Success: 0.20
#   Step 750, Global Reward: -4.0779, V2V Success: 0.20
#   Step 800, Global Reward: -4.5725, V2V Success: 0.20
#   Step 850, Global Reward: -4.6059, V2V Success: 0.20
#   Step 900, Global Reward: -4.6809, V2V Success: 0.20
#   Step 950, Global Reward: -4.1965, V2V Success: 0.20
# Episode 23/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.9684, V2V Success: 0.00
#   Step 50, Global Reward: -5.5000, V2V Success: 0.20
#   Step 100, Global Reward: -6.5400, V2V Success: 0.20
#   Step 150, Global Reward: -6.5887, V2V Success: 0.20
#   Step 200, Global Reward: -5.6300, V2V Success: 0.20
#   Step 250, Global Reward: -4.0318, V2V Success: 0.20
#   Step 300, Global Reward: -3.7348, V2V Success: 0.20
#   Step 350, Global Reward: -3.9287, V2V Success: 0.20
#   Step 400, Global Reward: -4.4052, V2V Success: 0.20
#   Step 450, Global Reward: -5.7408, V2V Success: 0.20
#   Step 500, Global Reward: -6.6500, V2V Success: 0.20
#   Step 550, Global Reward: -6.6340, V2V Success: 0.20
#   Step 600, Global Reward: -6.6771, V2V Success: 0.20
#   Step 650, Global Reward: -3.6279, V2V Success: 0.20
#   Step 700, Global Reward: -4.9377, V2V Success: 0.20
#   Step 750, Global Reward: -6.4970, V2V Success: 0.40
#   Step 800, Global Reward: -5.7348, V2V Success: 0.40
#   Step 850, Global Reward: -4.4316, V2V Success: 0.40
#   Step 900, Global Reward: -4.0479, V2V Success: 0.40
#   Step 950, Global Reward: -5.3164, V2V Success: 0.40
# Episode 24/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.2142, V2V Success: 0.00
#   Step 50, Global Reward: -7.2096, V2V Success: 0.00
#   Step 100, Global Reward: -7.1385, V2V Success: 0.00
#   Step 150, Global Reward: -7.0832, V2V Success: 0.00
#   Step 200, Global Reward: -4.6106, V2V Success: 0.20
#   Step 250, Global Reward: -4.9716, V2V Success: 0.20
#   Step 300, Global Reward: -4.4804, V2V Success: 0.20
#   Step 350, Global Reward: -4.7560, V2V Success: 0.20
#   Step 400, Global Reward: -5.0272, V2V Success: 0.20
#   Step 450, Global Reward: -5.2951, V2V Success: 0.40
#   Step 500, Global Reward: -5.4833, V2V Success: 0.60
#   Step 550, Global Reward: -5.5450, V2V Success: 0.60
#   Step 600, Global Reward: -4.5711, V2V Success: 0.60
#   Step 650, Global Reward: -4.4006, V2V Success: 0.60
#   Step 700, Global Reward: -3.5598, V2V Success: 0.60
#   Step 750, Global Reward: -4.1550, V2V Success: 0.60
#   Step 800, Global Reward: -4.5515, V2V Success: 0.60
#   Step 850, Global Reward: -4.4089, V2V Success: 0.60
#   Step 900, Global Reward: -3.3771, V2V Success: 0.60
#   Step 950, Global Reward: -3.9906, V2V Success: 0.60
# Episode 25/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -8.1425, V2V Success: 0.00
#   Step 50, Global Reward: -4.8130, V2V Success: 0.20
#   Step 100, Global Reward: -4.8902, V2V Success: 0.20
#   Step 150, Global Reward: -4.7580, V2V Success: 0.20
#   Step 200, Global Reward: -4.9258, V2V Success: 0.20
#   Step 250, Global Reward: -4.7972, V2V Success: 0.20
#   Step 300, Global Reward: -5.5581, V2V Success: 0.20
#   Step 350, Global Reward: -5.5552, V2V Success: 0.20
#   Step 400, Global Reward: -5.5695, V2V Success: 0.20
#   Step 450, Global Reward: -5.4874, V2V Success: 0.20
#   Step 500, Global Reward: -4.6498, V2V Success: 0.20
#   Step 550, Global Reward: -4.9279, V2V Success: 0.20
#   Step 600, Global Reward: -4.4291, V2V Success: 0.20
#   Step 650, Global Reward: -4.4566, V2V Success: 0.20
#   Step 700, Global Reward: -4.4057, V2V Success: 0.20
#   Step 750, Global Reward: -4.7469, V2V Success: 0.20
#   Step 800, Global Reward: -4.8488, V2V Success: 0.20
#   Step 850, Global Reward: -4.4988, V2V Success: 0.20
#   Step 900, Global Reward: -5.4127, V2V Success: 0.20
#   Step 950, Global Reward: -4.7799, V2V Success: 0.20
# Episode 26/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -8.1411, V2V Success: 0.00
#   Step 50, Global Reward: -4.1057, V2V Success: 0.20
#   Step 100, Global Reward: -5.6707, V2V Success: 0.20
#   Step 150, Global Reward: -4.5782, V2V Success: 0.20
#   Step 200, Global Reward: -4.9671, V2V Success: 0.20
#   Step 250, Global Reward: -4.1541, V2V Success: 0.40
#   Step 300, Global Reward: -5.0199, V2V Success: 0.40
#   Step 350, Global Reward: -5.5777, V2V Success: 0.40
#   Step 400, Global Reward: -4.7538, V2V Success: 0.40
#   Step 450, Global Reward: -4.7394, V2V Success: 0.40
#   Step 500, Global Reward: -4.0412, V2V Success: 0.40
#   Step 550, Global Reward: -4.0814, V2V Success: 0.40
#   Step 600, Global Reward: -4.2947, V2V Success: 0.40
#   Step 650, Global Reward: -4.8148, V2V Success: 0.40
#   Step 700, Global Reward: -4.1855, V2V Success: 0.40
#   Step 750, Global Reward: -4.7095, V2V Success: 0.40
#   Step 800, Global Reward: -3.7620, V2V Success: 0.40
#   Step 850, Global Reward: -3.7195, V2V Success: 0.40
#   Step 900, Global Reward: -4.3795, V2V Success: 0.40
#   Step 950, Global Reward: -4.8315, V2V Success: 0.40
# Episode 27/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -8.1540, V2V Success: 0.00
#   Step 50, Global Reward: -4.6198, V2V Success: 0.20
#   Step 100, Global Reward: -5.1833, V2V Success: 0.20
#   Step 150, Global Reward: -5.5008, V2V Success: 0.20
#   Step 200, Global Reward: -4.9327, V2V Success: 0.20
#   Step 250, Global Reward: -5.5301, V2V Success: 0.20
#   Step 300, Global Reward: -4.7212, V2V Success: 0.20
#   Step 350, Global Reward: -4.2724, V2V Success: 0.40
#   Step 400, Global Reward: -5.2965, V2V Success: 0.60
#   Step 450, Global Reward: -4.3885, V2V Success: 0.60
#   Step 500, Global Reward: -4.3837, V2V Success: 0.60
#   Step 550, Global Reward: -4.4752, V2V Success: 0.60
#   Step 600, Global Reward: -4.4202, V2V Success: 0.60
#   Step 650, Global Reward: -4.3745, V2V Success: 0.60
#   Step 700, Global Reward: -3.4946, V2V Success: 0.60
#   Step 750, Global Reward: -3.9961, V2V Success: 0.60
#   Step 800, Global Reward: -4.4520, V2V Success: 0.60
#   Step 850, Global Reward: -4.5006, V2V Success: 0.60
#   Step 900, Global Reward: -4.9013, V2V Success: 0.60
#   Step 950, Global Reward: -5.4365, V2V Success: 0.60
# Episode 28/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.2028, V2V Success: 0.00
#   Step 50, Global Reward: -6.4400, V2V Success: 0.20
#   Step 100, Global Reward: -7.0524, V2V Success: 0.20
#   Step 150, Global Reward: -4.4581, V2V Success: 0.40
#   Step 200, Global Reward: -5.0739, V2V Success: 0.40
#   Step 250, Global Reward: -5.8133, V2V Success: 0.40
#   Step 300, Global Reward: -5.7065, V2V Success: 0.40
#   Step 350, Global Reward: -2.8455, V2V Success: 0.40
#   Step 400, Global Reward: -3.3089, V2V Success: 0.60
#   Step 450, Global Reward: -3.5523, V2V Success: 0.60
#   Step 500, Global Reward: -3.5541, V2V Success: 0.60
#   Step 550, Global Reward: -3.9602, V2V Success: 0.60
#   Step 600, Global Reward: -3.6775, V2V Success: 0.60
#   Step 650, Global Reward: -3.9089, V2V Success: 0.60
#   Step 700, Global Reward: -4.1541, V2V Success: 0.60
#   Step 750, Global Reward: -3.2810, V2V Success: 0.60
#   Step 800, Global Reward: -3.6210, V2V Success: 0.60
#   Step 850, Global Reward: -3.1733, V2V Success: 0.60
#   Step 900, Global Reward: -3.4961, V2V Success: 0.60
#   Step 950, Global Reward: -4.4222, V2V Success: 0.60
# Episode 29/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -8.3239, V2V Success: 0.00
#   Step 50, Global Reward: -4.7276, V2V Success: 0.20
#   Step 100, Global Reward: -4.6724, V2V Success: 0.20
#   Step 150, Global Reward: -3.7741, V2V Success: 0.20
#   Step 200, Global Reward: -3.9024, V2V Success: 0.20
#   Step 250, Global Reward: -4.4598, V2V Success: 0.20
#   Step 300, Global Reward: -5.0051, V2V Success: 0.20
#   Step 350, Global Reward: -6.4257, V2V Success: 0.40
#   Step 400, Global Reward: -6.7582, V2V Success: 0.40
#   Step 450, Global Reward: -4.4167, V2V Success: 0.40
#   Step 500, Global Reward: -5.4477, V2V Success: 0.40
#   Step 550, Global Reward: -4.6257, V2V Success: 0.40
#   Step 600, Global Reward: -5.1897, V2V Success: 0.40
#   Step 650, Global Reward: -4.6721, V2V Success: 0.40
#   Step 700, Global Reward: -3.2013, V2V Success: 0.60
#   Step 750, Global Reward: -3.7467, V2V Success: 0.60
#   Step 800, Global Reward: -4.7588, V2V Success: 0.60
#   Step 850, Global Reward: -3.9740, V2V Success: 0.60
#   Step 900, Global Reward: -4.2940, V2V Success: 0.60
#   Step 950, Global Reward: -4.5725, V2V Success: 0.60
# Episode 30/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -7.2424, V2V Success: 0.00
#   Step 50, Global Reward: -5.7944, V2V Success: 0.20
#   Step 100, Global Reward: -6.9274, V2V Success: 0.40
#   Step 150, Global Reward: -7.1695, V2V Success: 0.40
#   Step 200, Global Reward: -7.2270, V2V Success: 0.40
#   Step 250, Global Reward: -6.4442, V2V Success: 0.40
#   Step 300, Global Reward: -5.9078, V2V Success: 0.40
#   Step 350, Global Reward: -6.1605, V2V Success: 0.40
#   Step 400, Global Reward: -5.6374, V2V Success: 0.40
#   Step 450, Global Reward: -5.3294, V2V Success: 0.40
#   Step 500, Global Reward: -4.8677, V2V Success: 0.40
#   Step 550, Global Reward: -5.0922, V2V Success: 0.40
#   Step 600, Global Reward: -4.4165, V2V Success: 0.40
#   Step 650, Global Reward: -4.0200, V2V Success: 0.40
#   Step 700, Global Reward: -4.5455, V2V Success: 0.40
#   Step 750, Global Reward: -4.2132, V2V Success: 0.40
#   Step 800, Global Reward: -4.4287, V2V Success: 0.40
#   Step 850, Global Reward: -4.2821, V2V Success: 0.40
#   Step 900, Global Reward: -4.3583, V2V Success: 0.40
#   Step 950, Global Reward: -4.7410, V2V Success: 0.40
# Episode 31/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.5011, V2V Success: 0.00
#   Step 50, Global Reward: -5.5234, V2V Success: 0.20
#   Step 100, Global Reward: -6.7043, V2V Success: 0.20
#   Step 150, Global Reward: -7.1895, V2V Success: 0.20
#   Step 200, Global Reward: -6.9603, V2V Success: 0.20
#   Step 250, Global Reward: -6.9306, V2V Success: 0.20
#   Step 300, Global Reward: -6.8266, V2V Success: 0.20
#   Step 350, Global Reward: -6.6844, V2V Success: 0.40
#   Step 400, Global Reward: -4.5287, V2V Success: 0.40
#   Step 450, Global Reward: -4.6915, V2V Success: 0.40
#   Step 500, Global Reward: -4.5903, V2V Success: 0.40
#   Step 550, Global Reward: -5.1080, V2V Success: 0.40
#   Step 600, Global Reward: -5.7345, V2V Success: 0.40
#   Step 650, Global Reward: -5.2178, V2V Success: 0.40
#   Step 700, Global Reward: -5.2128, V2V Success: 0.40
#   Step 750, Global Reward: -5.0988, V2V Success: 0.40
#   Step 800, Global Reward: -5.2392, V2V Success: 0.40
#   Step 850, Global Reward: -5.4678, V2V Success: 0.40
#   Step 900, Global Reward: -5.2580, V2V Success: 0.40
#   Step 950, Global Reward: -5.3185, V2V Success: 0.40
# Episode 32/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.2971, V2V Success: 0.00
#   Step 50, Global Reward: -6.9272, V2V Success: 0.20
#   Step 100, Global Reward: -6.4293, V2V Success: 0.20
#   Step 150, Global Reward: -6.8744, V2V Success: 0.20
#   Step 200, Global Reward: -6.7641, V2V Success: 0.40
#   Step 250, Global Reward: -7.1032, V2V Success: 0.40
#   Step 300, Global Reward: -6.0078, V2V Success: 0.40
#   Step 350, Global Reward: -6.4054, V2V Success: 0.40
#   Step 400, Global Reward: -6.8434, V2V Success: 0.40
#   Step 450, Global Reward: -4.3148, V2V Success: 0.40
#   Step 500, Global Reward: -4.7269, V2V Success: 0.40
#   Step 550, Global Reward: -5.0730, V2V Success: 0.40
#   Step 600, Global Reward: -4.2568, V2V Success: 0.40
#   Step 650, Global Reward: -4.3565, V2V Success: 0.40
#   Step 700, Global Reward: -4.4208, V2V Success: 0.40
#   Step 750, Global Reward: -4.3352, V2V Success: 0.40
#   Step 800, Global Reward: -4.2942, V2V Success: 0.40
#   Step 850, Global Reward: -4.3104, V2V Success: 0.40
#   Step 900, Global Reward: -4.3544, V2V Success: 0.40
#   Step 950, Global Reward: -3.3104, V2V Success: 0.40
# Episode 33/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -8.3254, V2V Success: 0.00
#   Step 50, Global Reward: -7.5503, V2V Success: 0.20
#   Step 100, Global Reward: -7.5731, V2V Success: 0.20
#   Step 150, Global Reward: -6.8606, V2V Success: 0.20
#   Step 200, Global Reward: -4.1365, V2V Success: 0.20
#   Step 250, Global Reward: -4.4176, V2V Success: 0.40
#   Step 300, Global Reward: -4.5755, V2V Success: 0.40
#   Step 350, Global Reward: -4.4555, V2V Success: 0.40
#   Step 400, Global Reward: -4.3432, V2V Success: 0.40
#   Step 450, Global Reward: -4.3080, V2V Success: 0.40
#   Step 500, Global Reward: -4.3089, V2V Success: 0.40
#   Step 550, Global Reward: -4.3151, V2V Success: 0.40
#   Step 600, Global Reward: -4.3960, V2V Success: 0.40
#   Step 650, Global Reward: -4.3888, V2V Success: 0.40
#   Step 700, Global Reward: -4.3794, V2V Success: 0.60
#   Step 750, Global Reward: -5.3615, V2V Success: 0.60
#   Step 800, Global Reward: -5.9738, V2V Success: 0.80
#   Step 850, Global Reward: -4.4563, V2V Success: 0.80
#   Step 900, Global Reward: -4.9869, V2V Success: 0.80
#   Step 950, Global Reward: -5.4765, V2V Success: 0.80
# Episode 34/100
#  Retrying in 1 seconds
# SUMO started successfully with command: sumo -c platoon.sumocfg --no-warnings --step-length 1.0 --no-step-log --time-to-teleport -1 --max-num-vehicles 25 --end 7200
# Created platoon 0 with route horizontal at time 0.0
# Created platoon 1 with route route_sn_straight at time 0.0
# Created platoon 2 with route route_we_straight at time 0.0
#   Step 0, Global Reward: -9.6647, V2V Success: 0.00
#   Step 50, Global Reward: -4.6811, V2V Success: 0.20
#   Step 100, Global Reward: -5.9134, V2V Success: 0.40
#   Step 150, Global Reward: -6.0007, V2V Success: 0.40

# %%
#!/usr/bin/env python3
import os
import sys
import random
import time

# Ensure SUMO is on PYTHONPATH; adjust SUMO_HOME if needed.
if 'SUMO_HOME' in os.environ:
    tools = os.path.join(os.environ['SUMO_HOME'], 'tools')
    sys.path.append(tools)
else:
    print("[ERROR] SUMO_HOME not set. Please export SUMO_HOME to your SUMO installation path.")
    sys.exit(1)

from sumolib import checkBinary  # noqa: E402
import traci  # noqa: E402

CFG = "platoon.sumocfg"  # uses single-intersection.net.xml and single-intersection.rou.xml
ROUTE_IDS = [
    "route_north_south",
    "route_west_east",
    "route_north_east",
    "route_west_south",
]
LEADER_VTYPE = "platoon_leader"
FOLLOWER_VTYPE = "platoon_follower"

def start_sumo():
    sumo_binary = checkBinary("sumo")
    cmd = [sumo_binary, "-c", CFG, "--step-length", "0.1", "--no-step-log", "true"]
    print(f"[INFO] Launching SUMO: {' '.join(cmd)}")
    traci.start(cmd)
    print("[INFO] TraCI connected")

def stop_sumo():
    try:
        traci.close()
    except Exception as e:
        print(f"[WARN] Error closing TraCI: {e}")

def make_platoon(platoon_idx, route_id, depart_time, leader_speed=11.11, headway=1.5):
    """
    Create one platoon of 4 vehicles on the given route.
    Vehicles depart with small time offsets to avoid spawn collisions,
    then set minimum gaps and speed to stick together.
    """
    leader_id = f"platoon{platoon_idx}_v0"
    follower_ids = [f"platoon{platoon_idx}_v{k}" for k in range(1, 4)]
    vehicle_ids = [leader_id] + follower_ids

    print(f"[DEBUG] Creating platoon {platoon_idx} on route '{route_id}' at t={depart_time:.1f}")
    print(f"[DEBUG]  Leader={leader_id}, Followers={follower_ids}")

    # Add leader first
    traci.vehicle.add(vehID=leader_id, routeID=route_id, typeID=LEADER_VTYPE, depart=str(depart_time))
    print(f"[DEBUG]  Added leader '{leader_id}' on route '{route_id}'")

    # Small depart offsets to prevent same-step insertion conflicts
    for i, fid in enumerate(follower_ids, start=1):
        traci.vehicle.add(vehID=fid, routeID=route_id, typeID=FOLLOWER_VTYPE,
                          depart=str(depart_time + i * 0.2))
        print(f"[DEBUG]  Added follower '{fid}' on route '{route_id}' with depart={depart_time + i*0.2:.1f}")

    # Step until leader exists in simulation
    while leader_id not in traci.vehicle.getIDList():
        traci.simulationStep()

    # Configure platoon behavior: speed and gap
    print(f"[DEBUG]  Setting leader '{leader_id}' speed to {leader_speed:.2f} m/s")
    traci.vehicle.setSpeed(leader_id, leader_speed)

    # Tighten minGap and set speed mode for followers
    for vid in vehicle_ids:
        vtype = LEADER_VTYPE if vid == leader_id else FOLLOWER_VTYPE
        # Use speed mode that obeys safety but allows speed commands: 0b000000000000 (0) is fully controlled,
        # 31 keeps safety checks; here we use 31 to avoid crashes.
        traci.vehicle.setSpeedMode(vid, 31)
        # Aggressive close-gap for followers
        if vtype == FOLLOWER_VTYPE:
            traci.vehicle.setMinGap(vid, 0.5)
        else:
            traci.vehicle.setMinGap(vid, 2.0)
        print(f"[DEBUG]   Configured '{vid}': vType={vtype}, minGap={traci.vehicle.getMinGap(vid):.2f}, speedMode=31")

    # Let the followers catch up to form a platoon
    return vehicle_ids

def main():
    start_sumo()
    try:
        # Sanity: ensure routes exist
        available_routes = set()
        # Route IDs from loaded route file are accessible via route.getIDList()
        traci.simulationStep()  # advance once so routes are registered
        available_routes.update(traci.route.getIDList())
        print(f"[INFO] Available routes in simulation: {sorted(list(available_routes))}")

        for rid in ROUTE_IDS:
            if rid not in available_routes:
                print(f"[ERROR] Missing route in SUMO: {rid}. Check single-intersection.rou.xml.")
                stop_sumo()
                return

        platoons = []
        # Stagger platoon departures
        sim_t = 0.0
        for p in range(5):
            route_id = random.choice(ROUTE_IDS)
            leader_speed = random.choice([10.0, 11.11, 12.0, 13.0])
            platoon = make_platoon(p, route_id, depart_time=sim_t, leader_speed=leader_speed, headway=1.5)
            platoons.append((p, route_id, platoon))
            sim_t += 6.0  # 6 seconds between platoons

        # Run simulation until end or all vehicles have arrived
        step = 0
        while traci.simulation.getMinExpectedNumber() > 0:
            traci.simulationStep()
            step += 1
            if step % 10 == 0:
                ids = traci.vehicle.getIDList()
                print(f"[TICK] t={traci.simulation.getTime():.1f} s | active={len(ids)} | ids={list(ids)}")

        print("[INFO] Simulation complete.")
    except traci.exceptions.TraCIException as e:
        print(f"[ERROR] TraCI exception: {e}")
    except Exception as e:
        print(f"[ERROR] Unexpected: {e}")
    finally:
        stop_sumo()

if __name__ == "__main__":
    main()
# Out:
# [INFO] Launching SUMO: /usr/share/sumo/bin/sumo -c platoon.sumocfg --step-length 0.1 --no-step-log true
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 38517 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 35241 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 51529 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 57005 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 60611 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 54071 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 39753 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 48637 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 46135 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 57335 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 53803 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 44505 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 40627 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 59253 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 59497 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 59493 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 41743 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 60169 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 51667 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 49137 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 43221 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 60067 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 56473 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 51585 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 34873 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 33013 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 40521 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 56447 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 39095 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 46277 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 43659 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 38877 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 33737 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 46815 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 51511 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 46209 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 50523 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 36517 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 40537 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 56819 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 60391 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 60007 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 59329 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 56037 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 46071 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 52857 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 55931 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 50269 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 44409 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 56345 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 35599 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 39547 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 39845 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 37193 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 35663 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 50139 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 35865 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 37567 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 34301 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#  Retrying in 1 seconds
# /usr/share/sumo/tools/traci/main.py:174: UserWarning: Could not connect to TraCI server using port 46169 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# ---------------------------------------------------------------------------
# FatalTraCIError                           Traceback (most recent call last)
# /tmp/ipython-input-1390500506.py in <cell line: 0>()
#     130
#     131 if __name__ == "__main__":
# --> 132     main()
#
# /tmp/ipython-input-1390500506.py in main()
#      87
#      88 def main():
# ---> 89     start_sumo()
#      90     try:
#      91         # Sanity: ensure routes exist
#
# /tmp/ipython-input-1390500506.py in start_sumo()
#      30     cmd = [sumo_binary, "-c", CFG, "--step-length", "0.1", "--no-step-log", "true"]
#      31     print(f"[INFO] Launching SUMO: {' '.join(cmd)}")
# ---> 32     traci.start(cmd)
#      33     print("[INFO] TraCI connected")
#      34
#
# /usr/share/sumo/tools/traci/main.py in start(cmd, port, numRetries, label, verbose, traceFile, traceGetters, stdout, doSwitch)
#     168         sumoProcess = subprocess.Popen(cmd2, stdout=stdout)
#     169         try:
# --> 170             return init(sumoPort, numRetries, "localhost", label, sumoProcess, doSwitch)
#     171         except TraCIException as e:
#     172             if port is not None:
#
# /usr/share/sumo/tools/traci/main.py in init(port, numRetries, host, label, proc, doSwitch)
#     135     pool concurrently.
#     136     """
# --> 137     _connections[label] = connect(port, numRetries, host, proc)
#     138     if doSwitch:
#     139         switch(label)
#
# /usr/share/sumo/tools/traci/main.py in connect(port, numRetries, host, proc, waitBetweenRetries)
#     126                 print(" Retrying in %s seconds" % waitBetweenRetries)
#     127                 time.sleep(waitBetweenRetries)
# --> 128     raise FatalTraCIError("Could not connect in %s tries" % (numRetries + 1))
#     129
#     130
#
# FatalTraCIError: Could not connect in 1 tries

# %%
# ===== FILE ORGANIZATION CELL =====
import shutil
import os

# Your files are already here! Let's organize them
current_files = [f for f in os.listdir('.') if f.endswith('.py')]
print("Found files:", current_files)

# Move files to Classes directory
classes_files = ['Environment_Platoon.py', 'networks.py', 'noise.py', 'buffer.py']

for file in classes_files:
    if os.path.exists(file):
        shutil.move(file, f'Classes/{file}')
        print(f"✅ Moved {file} to Classes/")

# Create __init__.py
with open('Classes/__init__.py', 'w') as f:
    f.write('# Classes module\n')

print("📁 Files organized!")
print("Root:", [f for f in os.listdir('.') if f.endswith('.py')])
print("Classes:", os.listdir('Classes'))
# Out:
# Found files: []
# 📁 Files organized!
# Root: []
# Classes: ['__init__.py']

# %%
pip install torch torchvision torchaudio scipy numpy tplotlib
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)

# %%
# ===== MAIN TRAINING SCRIPT =====
import numpy as np
import torch as T
import time
import os
import scipy.io
import sys
import math

# Add paths
sys.path.append('.')
sys.path.append('./Classes')

# Import modules
import Classes.Environment_Platoon as ENV
from ddpg_torch import HybridMADDPGAgent

# Try SUMO import
try:
    import traci
    SUMO_AVAILABLE = True
    print("✅ SUMO available!")
except:
    SUMO_AVAILABLE = False
    print("⚠️ Using fallback simulation")

class SUMOEnhancedEnvironment(ENV.Environ):
    """Enhanced environment with SUMO integration"""

    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.sumo_running = False
        self.step_count = 0

    def start_sumo(self):
        """Start SUMO if available"""
        if not SUMO_AVAILABLE:
            return False

        try:
            # Create simple SUMO config
            net_xml = '''<?xml version="1.0" encoding="UTF-8"?>
<net version="1.16">
    <edge id="E1" from="J1" to="J2" priority="1" numLanes="3" speed="15.00"/>
    <junction id="J1" type="priority" x="0.00" y="250.00"/>
    <junction id="J2" type="priority" x="1000.00" y="250.00"/>
</net>'''

            with open('simple.net.xml', 'w') as f:
                f.write(net_xml)

            config_xml = '''<?xml version="1.0" encoding="UTF-8"?>
<configuration>
    <input><net-file value="simple.net.xml"/></input>
    <time><begin value="0"/><step-length value="0.1"/></time>
</configuration>'''

            with open('simple.sumocfg', 'w') as f:
                f.write(config_xml)

            traci.start(["sumo", "-c", "simple.sumocfg", "--no-warnings", "--no-step-log"])
            self.sumo_running = True
            print("✅ SUMO started!")
            return True
        except Exception as e:
            print(f"⚠️ SUMO failed: {e}")
            return False

    def update_with_sumo(self):
        """Update positions using SUMO if available"""
        if self.sumo_running:
            try:
                traci.simulationStep()
                self.step_count += 1
                # Simple position update from SUMO
                for i, vehicle in enumerate(self.vehicles):
                    # Add small random movement to simulate SUMO integration
                    vehicle.position[0] += np.random.uniform(-0.5, 0.5)
                    vehicle.position[1] += np.random.uniform(-0.5, 0.5)
                    # Keep within bounds
                    vehicle.position[0] = np.clip(vehicle.position[0], 0, self.width)
                    vehicle.position[1] = np.clip(vehicle.position[1], 0, self.height)
                return True
            except:
                self.sumo_running = False
                return False
        return False

    def new_random_game(self, n_veh=0):
        """Enhanced episode initialization"""
        super().new_random_game(n_veh)

        if not self.sumo_running:
            self.start_sumo()

        print(f"🎮 New episode (SUMO: {'Active' if self.sumo_running else 'Fallback'})")

    def act_for_training(self, actions):
        """Enhanced training step with SUMO"""
        # Update with SUMO if available
        self.update_with_sumo()

        # Update channels with new positions
        self.renew_channel(self.n_Veh, self.size_platoon)
        self.renew_channels_fastfading()

        # Call parent method
        return super().act_for_training(actions)

    def __del__(self):
        if self.sumo_running:
            try:
                traci.close()
            except:
                pass

def get_state(env, idx, size_platoon):
    """Get state for agent"""
    V2I_abs = (env.V2I_channels_abs[idx * size_platoon] - 60) / 60.0
    V2V_abs = (env.V2V_channels_abs[idx * size_platoon, idx * size_platoon + (1 + np.arange(size_platoon - 1))] - 60)/60.0
    V2I_fast = (env.V2I_channels_with_fastfading[idx * size_platoon, :] - env.V2I_channels_abs[idx * size_platoon] + 10) / 35
    V2V_fast = (env.V2V_channels_with_fastfading[idx * size_platoon, idx * size_platoon + (1 + np.arange(size_platoon - 1)), :] -
                env.V2V_channels_abs[idx * size_platoon, idx * size_platoon + (1 + np.arange(size_platoon - 1))].reshape(size_platoon - 1, 1) + 10) / 35
    Interference = (-env.Interference_all[idx] - 60) / 60
    AoI_levels = env.AoI[idx] / (int(env.time_slow / env.time_fast))
    V2V_load_remaining = np.asarray([env.V2V_demand[idx] / env.V2V_demand_size])

    state = np.concatenate((np.reshape(V2I_abs, -1), np.reshape(V2I_fast, -1), np.reshape(V2V_abs, -1),
                           np.reshape(V2V_fast, -1), np.reshape(Interference, -1), np.reshape(AoI_levels, -1),
                           V2V_load_remaining), axis=0)
    return np.nan_to_num(state, nan=0.0)

def main():
    print("🚗🤖 Starting SUMO-Enhanced MADDPG Training!")

    # Parameters (optimized for quick demo)
    size_platoon = 4
    n_veh = 20
    n_platoon = int(n_veh / size_platoon)
    n_RB = 3
    n_S = 2
    Gap = 25
    max_power = 30
    V2I_min = 540
    bandwidth = 180000
    V2V_size = 4000 * 8

    # Network parameters (reduced for faster training)
    batch_size = 32
    memory_size = 10000
    gamma = 0.99
    alpha = 0.001
    beta = 0.001

    # Network architecture (smaller for speed)
    C_fc1_dims = 256
    C_fc2_dims = 128
    C_fc3_dims = 64
    A_fc1_dims = 256
    A_fc2_dims = 128
    tau = 0.01

    # Lane configurations
    up_lanes = [0.875, 2.625, 125.875, 127.625, 250.875, 252.625]
    down_lanes = [122.375, 124.125, 247.375, 249.125, 372.375, 374.125]
    left_lanes = [0.875, 2.625, 217.375, 219.125, 433.875, 435.625]
    right_lanes = [213.875, 215.625, 430.375, 432.1215, 646.875, 648.625]
    width = 1000
    height = 500

    print(f'🛣️ Environment: {n_veh} vehicles, {n_platoon} platoons')

    # Initialize enhanced environment
    env = SUMOEnhancedEnvironment(
        down_lane=down_lanes, up_lane=up_lanes, left_lane=left_lanes, right_lane=right_lanes,
        width=width, height=height, n_veh=n_veh, size_platoon=size_platoon,
        n_RB=n_RB, V2I_min=V2I_min, BW=bandwidth, V2V_SIZE=V2V_size, Gap=Gap
    )

    env.new_random_game()

    # Get dimensions
    n_input = len(get_state(env=env, idx=0, size_platoon=size_platoon))
    n_output = 3
    print(f"🧠 Network: input={n_input}, output={n_output}")

    # Initialize agents
    agents = []
    for i in range(n_platoon):
        agent = HybridMADDPGAgent(
            alpha=alpha, beta=beta, input_dims=n_input, tau=tau,
            n_actions=n_output, gamma=gamma, max_size=memory_size,
            C_fc1_dims=C_fc1_dims, C_fc2_dims=C_fc2_dims, C_fc3_dims=C_fc3_dims,
            A_fc1_dims=A_fc1_dims, A_fc2_dims=A_fc2_dims,
            batch_size=batch_size, n_agents=n_platoon, agent_name=i
        )
        agents.append(agent)

    print(f"🤖 {len(agents)} agents initialized!")

    # Training parameters
    n_episode = 30  # Quick demo
    n_step_per_episode = 50

    # Storage
    record_global_reward = np.zeros(n_episode)

    start_time = time.time()
    print(f"🚀 Starting training ({n_episode} episodes)...")

    # Training loop
    for i_episode in range(n_episode):
        try:
            if i_episode % 5 == 0:
                status = "SUMO" if env.sumo_running else "Fallback"
                print(f'📊 Episode {i_episode+1}/{n_episode} ({status})')

            env.new_random_game()
            states = [get_state(env, agent_id, size_platoon) for agent_id in range(n_platoon)]

            episode_reward = 0
            for i_step in range(n_step_per_episode):
                # Get actions
                actions_for_env = []
                for agent_id in range(n_platoon):
                    action = agents[agent_id].choose_action(states[agent_id])
                    action = np.nan_to_num(action, nan=0.0)

                    rb_selection = int(np.clip(action[0] * n_RB, 0, n_RB - 1))
                    mode_selection = int(np.clip(action[1] * n_S, 0, n_S - 1))
                    power_selection = np.clip(action[2], 1e-6, max_power)

                    actions_for_env.append([rb_selection, mode_selection, power_selection])

                action_temp = np.array(actions_for_env)

                # Environment step
                per_user_reward, global_reward, platoon_AoI, V2I_rate, V2V_rate, Demand, interference_val = env.act_for_training(action_temp)
                episode_reward += global_reward

                # Learn
                next_states = [get_state(env, agent_id, size_platoon) for agent_id in range(n_platoon)]

                for agent_id in range(n_platoon):
                    agents[agent_id].remember(
                        states[agent_id], action_temp[agent_id],
                        per_user_reward[agent_id], next_states[agent_id], False
                    )
                    agents[agent_id].learn()

                states = next_states

            record_global_reward[i_episode] = episode_reward / n_step_per_episode

        except Exception as e:
            print(f"⚠️ Episode {i_episode} error: {e}")
            record_global_reward[i_episode] = -1

    # Training complete
    training_time = time.time() - start_time
    avg_reward = np.mean(record_global_reward)

    print(f'\n🎉 Training Complete!')
    print(f'⏱️  Time: {training_time:.1f}s')
    print(f'📈 Average reward: {avg_reward:.4f}')
    print(f'🏆 Best reward: {np.max(record_global_reward):.4f}')
    print(f'🚗 SUMO: {"Success" if env.sumo_running else "Fallback"}')

    # Save results
    scipy.io.savemat('result/sumo_maddpg_results.mat', {
        'global_reward': record_global_reward,
        'time': training_time,
        'sumo_used': env.sumo_running
    })
    print('💾 Results saved!')

    return record_global_reward

# Run training
rewards = main()

# Visualize results
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.plot(rewards, 'b-', linewidth=2)
plt.title('Training Progress')
plt.xlabel('Episode')
plt.ylabel('Global Reward')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(rewards[-10:], 'g-', linewidth=2, marker='o')
plt.title('Final Episodes')
plt.xlabel('Episode')
plt.ylabel('Global Reward')
plt.grid(True)

plt.tight_layout()
plt.show()

print(f"\n🎯 Training Summary:")
print(f"   Final reward: {rewards[-1]:.4f}")
print(f"   Total improvement: {((rewards[-1] - rewards[0])/abs(rewards[0])*100 if rewards[0] != 0 else 0):.1f}%")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2260658189.py in <cell line: 0>()
#      13
#      14 # Import modules
# ---> 15 import Classes.Environment_Platoon as ENV
#      16 from ddpg_torch import HybridMADDPGAgent
#      17
#
# ModuleNotFoundError: No module named 'Classes.Environment_Platoon'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
